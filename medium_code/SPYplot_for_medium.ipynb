# %%
import numpy as np  
import pandas as pd   
import matplotlib.pyplot as plt  
from matplotlib.dates import DateFormatter

# %%
year = '2020'

spy_file = 'SPY_'+year+'+.csv' #Contains data from 12/30/2019 - 3/04/2021
vix_file = '^VIX_'+year+'.csv' #Contains data from 1/2/2020 - 12/31/2020

spy_data = pd.read_csv(spy_file, index_col = 'Date')
spy_data.drop(['High','Open','Close','Low','Volume'],axis=1, inplace=True)

vix_data = pd.read_csv(vix_file, index_col = 'Date')
vix_data.drop(['Adj Close','High','Low','Close','Volume'],axis=1, inplace=True)

data = pd.merge(spy_data,vix_data,left_index=True,right_index=True,how='left')
data.rename(columns = {"Adj Close": "SPY"}, inplace=True)
data.rename(columns = {"Open": "VIX"}, inplace=True)
data = data.reset_index(level=['Date']);
data.Date = pd.to_datetime(data.Date, format='%Y-%m-%d')

len(data)
# Out:
# 297

# %%
t2 = data[(data.Date <= (data.Date[45] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[45])].Date
y2 = data[(data.Date <= (data.Date[45] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[45])].SPY
t3 = data[(data.Date <= (data.Date[100] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[100])].Date
y3 = data[(data.Date <= (data.Date[100] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[100])].SPY
t4 = data[(data.Date <= (data.Date[155] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[155])].Date
y4 = data[(data.Date <= (data.Date[155] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[155])].SPY
t5 = data[(data.Date <= (data.Date[210] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[210])].Date
y5 = data[(data.Date <= (data.Date[210] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[210])].SPY
t6 = data[(data.Date <= (data.Date[9] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[9])].Date
y6 = data[(data.Date <= (data.Date[9] + pd.Timedelta(days=45)))&
                               (data.Date>data.Date[9])].SPY

# %%
fig = plt.figure(figsize=(16,6),dpi=100) 
ax1 = fig.add_subplot(1,1,1)

x = data[data['Date'].dt.year == 2020].Date
y1 = data[data['Date'].dt.year == 2020].SPY
#y2 = data[data['Date'].dt.year == 2020].VIX

date_form = DateFormatter("%m-%y")
ax1.xaxis.set_major_formatter(date_form)
ax1.plot(x, y1,color=(.6,.6,.6), linewidth=2, linestyle='-', label='SPY')
ax1.plot(t2,y2,color='k')
ax1.plot(t3,y3,color='g')
ax1.plot(t4,y4,color='b')
ax1.plot(t5,y5,color='orange')
ax1.plot(t6,y6,color='red')
ax1.legend(loc='upper left', frameon=True) 
plt.title('SPY: 2020',fontweight='bold');

plt.savefig('sim_example.png',bbox_inches = 'tight',pad_inches=0.5,facecolor='w')

# %%
len(x)
# Out:
# 253

# %%
# calculate daily logarithmic return
data['SPY Returns'] = np.log(data.SPY.pct_change()+1.)
      
# calculate daily standard deviation of returns
daily_std = np.std(data['SPY Returns'])
  
# annualized daily standard deviation
std = daily_std * len(x) ** 0.5

# %%
data.head()
# Out:
#         Date         SPY    VIX  SPY Returns
# 0 2019-12-30  315.193817    NaN          NaN
# 1 2019-12-31  315.959503    NaN     0.002426
# 2 2020-01-02  318.914307  13.46     0.009308
# 3 2020-01-03  316.499451  15.01    -0.007601
# 4 2020-01-06  317.706909  15.45     0.003808

# %%
realized_vol = []
for index, row in data.iterrows():
    temp = data['SPY Returns'][(data.Date <= (data.Date[index] + pd.Timedelta(days=30)))&
                               (data.Date>data.Date[index])]
    realized_vol.append(round((np.std(temp)* len(data) ** 0.5)*100,2))

data['Realized SPY Vol'] = realized_vol

# %%
data.head()
# Out:
#         Date         SPY    VIX  SPY Returns
# 0 2019-12-30  315.193817    NaN          NaN
# 1 2019-12-31  315.959503    NaN     0.002426
# 2 2020-01-02  318.914307  13.46     0.009308
# 3 2020-01-03  316.499451  15.01    -0.007601
# 4 2020-01-06  317.706909  15.45     0.003808

# %%
data_2020 = data[data['Date'].dt.year == 2020]

data_2020 = data_2020.reset_index(drop='true')
data_2020.head()
# Out:
#         Date         SPY    VIX  SPY Returns  Realized SPY Vol
# 0 2020-01-02  318.914307  13.46     0.009308             12.74
# 1 2020-01-03  316.499451  15.01    -0.007601             12.74
# 2 2020-01-06  317.706909  15.45     0.003808             14.08
# 3 2020-01-07  316.813568  13.84    -0.002816             14.01
# 4 2020-01-08  318.502075  15.16     0.005316             14.16

# %%
fig = plt.figure(figsize=(16,6),dpi=100) 
ax1 = fig.add_subplot(1,1,1)

plt.title('2020: Realized Vol vs. VIX',fontweight='bold');

x = data_2020.Date
y1 = data_2020.VIX
y2 = data_2020['Realized SPY Vol']

date_form = DateFormatter("%m-%y")
ax1.xaxis.set_major_formatter(date_form)
ax1.set_ylim(0,100)

ax1.plot(x, y1,color='k', linewidth=2, linestyle='-', label='VIX')
ax1.legend(loc='upper left', frameon=True) 

ax2 = ax1.twinx()
ax2.set_ylim(0,100)

ax2.plot(x,y2,color='r',linewidth=2, linestyle='-', label='Realized Vol')
ax2.legend(loc='upper right', frameon=True);

plt.savefig('2020_vix.png',bbox_inches = 'tight',pad_inches=0.5,facecolor='w')

# %%
RV_mean = data_2020['Realized SPY Vol'].mean()
VOL_mean = data_2020.VIX.mean()

# %%
print('In 2020, the average implied volatility was: '+str(round(VOL_mean,2))+'%.')
print('In 2020, the average realized volatility was: '+str(round(RV_mean,2))+'%.')
# Out:
# In 2020, the average implied volatility was: 29.51%.
# In 2020, the average realized volatility was: 27.88%.

# %%
percent_overstatement = round(100.*(len(np.where(data_2020.VIX > data_2020['Realized SPY Vol'])[0])/len(data_2020)),2)
print("In 2020, the VIX overstated the 30-day realized volatility {}% of the time.".format(percent_overstatement))
# Out:
# In 2020, the VIX overstated the 30-day realized volatility 71.15% of the time.
